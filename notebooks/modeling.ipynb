# %%
from dotenv import load_dotenv
import os

import pandas as pd
pd.options.display.max_columns = None
import seaborn as sns
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import precision_recall_fscore_support as score
import mlflow
import datetime
import warnings
warnings.filterwarnings("ignore")

import os

# %%
load_dotenv("../backend/src/.env")
DagsHub_username = os.getenv("DagsHub_username")
DagsHub_token=os.getenv("DagsHub_token")

# %%
print(DagsHub_username)
# Out:
# rami4real

# %%
os.environ['MLFLOW_TRACKING_USERNAME']= DagsHub_username
os.environ["MLFLOW_TRACKING_PASSWORD"] = DagsHub_token

# %%
mlflow.set_tracking_uri('https://dagshub.com/rami4real/mymlproject.mlflow') #your mlfow tracking uri
mlflow.set_experiment("churn-experiment")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/566ae890f7ca4c2db92c2a642aca7189', creation_time=1733732561769, experiment_id='0', last_update_time=1733732561769, lifecycle_stage='active', name='churn-experiment', tags={}>

# %%
data_train = pd.read_csv("../data/customer_churn_train.csv")
data_test = pd.read_csv("../data/customer_churn_test.csv")

# %%
x_train = data_train.drop(['Churn'],axis = 1)  # All rows except the last two
y_train = data_train['Churn']   # The last row
x_test = data_test.drop(['Churn'],axis = 1)   # All rows except the last two
y_test = data_test['Churn'] 
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404164 entries, 0 to 404163
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Age                404164 non-null  float64
#  1   Gender             404164 non-null  int64
#  2   Tenure             404164 non-null  float64
#  3   Usage Frequency    404164 non-null  float64
#  4   Support Calls      404164 non-null  float64
#  5   Payment Delay      404164 non-null  float64
#  6   Subscription Type  404164 non-null  int64
#  7   Contract Length    404164 non-null  int64
#  8   Total Spend        404164 non-null  float64
#  9   Last Interaction   404164 non-null  float64
# dtypes: float64(7), int64(3)
# memory usage: 30.8 MB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101042 entries, 0 to 101041
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Age                101042 non-null  float64
#  1   Gender             101042 non-null  int64
#  2   Tenure             101042 non-null  float64
#  3   Usage Frequency    101042 non-null  float64
#  4   Support Calls      101042 non-null  float64
#  5   Payment Delay      101042 non-null  float64
#  6   Subscription Type  101042 non-null  int64
#  7   Contract Length    101042 non-null  int64
#  8   Total Spend        101042 non-null  float64
#  9   Last Interaction   101042 non-null  float64
# dtypes: float64(7), int64(3)
# memory usage: 7.7 MB

# %%
x_test
# Out:
#              Age  Gender    Tenure  Usage Frequency  Support Calls  \
# 0       1.601809       0  1.429999         0.033086      -0.585052
# 1      -0.765883       1  0.327749         1.309289      -0.904173
# 2      -1.081576       1  0.791855         0.961234      -0.904173
# 3       0.812578       1 -1.238606         0.613178       0.053192
# 4      -0.371268       0 -0.716488         0.845215       0.372314
# ...          ...     ...       ...              ...            ...
# 101037  0.417963       0 -1.586686        -0.314970      -1.223295
# 101038 -0.213422       0  1.197947         0.729197      -0.585052
# 101039  0.102271       1 -1.238606        -1.011081       0.053192
# 101040 -1.160499       0  0.733841        -1.591174      -0.904173
# 101041  0.575809       0  0.849868        -1.011081       1.967923
#
#         Payment Delay  Subscription Type  Contract Length  Total Spend  \
# 0           -1.478710                  2                0    -0.897088
# 1            0.296190                  2                0    -0.142193
# 2           -0.058790                  1                2     0.208778
# 3           -0.295443                  0                2    -0.334555
# 4           -0.058790                  2                0    -0.664738
# ...               ...                ...              ...          ...
# 101037       0.177864                  1                0     0.158802
# 101038      -0.295443                  2                0     0.817822
# 101039       0.296190                  2                0    -0.263423
# 101040      -1.360383                  0                0     0.233155
# 101041      -0.295443                  1                2     1.295975
#
#         Last Interaction
# 0              -0.884100
# 1              -1.464937
# 2               0.742241
# 3              -0.651766
# 4              -0.651766
# ...                  ...
# 101037         -0.070929
# 101038         -1.581104
# 101039         -1.348769
# 101040         -0.303264
# 101041          0.393740
#
# [101042 rows x 10 columns]

# %%
y_test
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 101037    0
# 101038    0
# 101039    0
# 101040    0
# 101041    0
# Name: Churn, Length: 101042, dtype: int64

# %%
def train_and_evaluate_model(model, x_train, y_train, x_test, y_test):
    """
    Train the model and evaluate it on test data.
    Returns the classification report as a dictionary.
    """
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    return report

# %%
models = {
    "Linear SVC": LinearSVC(),
    "Naive Bayes": GaussianNB(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "MLP Classifier": MLPClassifier(random_state=42)
}

# %%
results = {}

# Train and evaluate each model
for model_name, model in models.items():
    print(f"Training model: {model_name}...")
    report = train_and_evaluate_model(model, x_train, y_train, x_test, y_test)
    results[model_name] = {
        "F1-Score (0)": report["0"]["f1-score"],
        "F1-Score (1)": report["1"]["f1-score"]
    }
# Out:
# Training model: Linear SVC...
# Training model: Naive Bayes...
# Training model: Random Forest...
# Training model: XGBoost...
# Training model: K-Nearest Neighbors...
# Training model: MLP Classifier...

# %%
comparison = pd.DataFrame([
    {"Model": model_name, "F1 Score": max(scores.values())}  # Use max F1-Score for comparison
    for model_name, scores in results.items()
]).sort_values(by="F1 Score", ascending=False)

print("\nModel Comparison (sorted by F1 Score):")
print(comparison)
# Out:
# Model Comparison (sorted by F1 Score):
#                  Model  F1 Score
# 2        Random Forest  0.945193
# 3              XGBoost  0.943054
# 5       MLP Classifier  0.933756
# 4  K-Nearest Neighbors  0.908235
# 1          Naive Bayes  0.866768
# 0           Linear SVC  0.832492

# %%
# Create a comparative table
results_df = pd.DataFrame(results)
print("\nComparative Table of F1-Scores:")

# Display the table
results_df
# Out:
# Comparative Table of F1-Scores:
#               Linear SVC  Naive Bayes  Random Forest   XGBoost  \
# F1-Score (0)    0.801039     0.844923       0.922662  0.920188
# F1-Score (1)    0.832492     0.866768       0.945193  0.943054
#
#               K-Nearest Neighbors  MLP Classifier
# F1-Score (0)             0.883508        0.909644
# F1-Score (1)             0.908235        0.933756

# %% [markdown]
# ## Best Performers:
# For Class 0, Random Forest achieves the highest F1-score of 0.922662, followed closely by XGBoost (0.920188) and MLP Classifier (0.909644).
#
# For Class 1, Random Forest leads with an F1-score of 0.945193, closely followed by XGBoost (0.943054) and MLP Classifier (0.933756).
# ## Ensemble methods like Random Forest and XGBoost consistently outperform other algorithms in both classes, suggesting their robustness for handling churn data.

# %% [markdown]
# ### XGBoost

# %%
with mlflow.start_run(run_name='XGBoost'):
    mlflow.log_param("data_train","../data/customer_churn_train.csv")
    mlflow.log_param("data_test","../data/customer_churn_test.csv")
    mlflow.log_param("data_version","v1.0")
    xgb_model = XGBClassifier()
    params = xgb_model.get_params()
    mlflow.log_params(params)
    mlflow.set_tag(key="model", value="XGBoost")
    xgb_model.fit(x_train, y_train)
    train_features_name = f'{x_train=}'.split('=')[0]
    train_label_name = f'{y_train=}'.split('=')[0]
    mlflow.set_tag(key="train_features_name", value=train_features_name)
    mlflow.set_tag(key="train_label_name", value=train_label_name)
    predicted = xgb_model.predict(x_test)
    precision, recall, fscore, support = score(y_test, predicted, average='macro')
    
    mlflow.log_metric("Precision_test", precision)
    mlflow.log_metric("Recall_test", recall)
    mlflow.log_metric("F1_score_test", fscore)
    
    # Log the trained model as an artifact
    mlflow.sklearn.log_model(xgb_model, artifact_path="ML_models")
# Out:
# 2024/12/09 15:46:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGBoost at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0/runs/fed913d3496c465683f3616f78fbe798
# 🧪 View experiment at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0

# %%
with mlflow.start_run(run_name='Random Forest'):
    # Log dataset information
    mlflow.log_param("data_train", "../data/customer_churn_train.csv")
    mlflow.log_param("data_test", "../data/customer_churn_test.csv")
    mlflow.log_param("data_version", "v1.0")
    
    # Initialize and log Random Forest model parameters
    rf_model = RandomForestClassifier()
    params = rf_model.get_params()
    mlflow.log_params(params)
    mlflow.set_tag(key="model", value="Random Forest")
    
    # Train the Random Forest model
    rf_model.fit(x_train, y_train)
    
    # Log feature and label names as tags
    train_features_name = f'{x_train=}'.split('=')[0]
    train_label_name = f'{y_train=}'.split('=')[0]
    mlflow.set_tag(key="train_features_name", value=train_features_name)
    mlflow.set_tag(key="train_label_name", value=train_label_name)
    
    # Make predictions and calculate metrics
    predicted = rf_model.predict(x_test)
    precision, recall, fscore, support = score(y_test, predicted, average='macro')
    
    # Log metrics
    mlflow.log_metric("Precision_test", precision)
    mlflow.log_metric("Recall_test", recall)
    mlflow.log_metric("F1_score_test", fscore)
    
    # Log the trained model as an artifact
    mlflow.sklearn.log_model(rf_model, artifact_path="ML_models")
# Out:
# 2024/12/09 15:47:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0/runs/2c3da176f4414edea4ff350bffd5ddc0
# 🧪 View experiment at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0

# %% [markdown]
# ## Finetuning

# %% [markdown]
# XGBoost with Grid Search

# %%
with mlflow.start_run(run_name='XGBoost'):
    mlflow.log_param("data_train","../data/customer_churn_train.csv")
    mlflow.log_param("data_test","../data/customer_churn_test.csv")
    mlflow.log_param("data_version","v1.0")
    xgb_params = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
    }
    xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
    xgb_grid = GridSearchCV(
    estimator=xgb_model,
    param_grid=xgb_params,
    cv=5,
    scoring='f1_weighted',
    n_jobs=-1,
    verbose=2)
    print("\nTuning XGBoost model...")
    xgb_grid.fit(x_train, y_train)

    print(f"\nBest parameters for XGBoost: {xgb_grid.best_params_}")
    xgb_best_model = xgb_grid.best_estimator_
    xgb_best_score = xgb_grid.best_score_
    print(f"Best F1 Score for XGBoost (CV): {xgb_best_score:.4f}")
    predicted = xgb_best_model.predict(x_test)

    precision, recall, fscore, support = score(y_test, predicted, average='macro')
    
    # Log metrics
    mlflow.log_metric("Precision_test", precision)
    mlflow.log_metric("Recall_test", recall)
    mlflow.log_metric("F1_score_test", fscore)
    
    # Log the trained model as an artifact
    mlflow.sklearn.log_model(rf_model, artifact_path="ML_models")
# Out:
# Tuning XGBoost model...
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:03:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:04:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:05:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:06:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/rami/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:07:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
# ...
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  36.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   8.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  15.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  21.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  31.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  15.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  22.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  24.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  30.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   9.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  14.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  22.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  35.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  10.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  18.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   9.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  13.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  19.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  22.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  18.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   8.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  29.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  24.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  16.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  14.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  24.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   7.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  17.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  27.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  24.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   7.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  24.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  25.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  35.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  21.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  21.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  29.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  15.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  25.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  22.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  21.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  16.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  23.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  24.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  35.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  16.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  24.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  22.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  30.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  22.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  11.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  21.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  27.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  14.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  22.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  36.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   9.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  19.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  28.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  13.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  10.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  19.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  21.8s
# 🏃 View run XGBoost at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0/runs/1498ce246a114ce7a5cd3f325b99c248
# 🧪 View experiment at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0

# %% [markdown]
# Random Forest with Reduced Grid Search

# %%
with mlflow.start_run(run_name='XGBoost'):
    mlflow.log_param("data_train","../data/customer_churn_train.csv")
    mlflow.log_param("data_test","../data/customer_churn_test.csv")
    mlflow.log_param("data_version","v1.0")
    rf_params_reduced = {
    'n_estimators': [100, 200],
    'max_depth': [10, None],
    'min_samples_split': [5],
    'min_samples_leaf': [2, 4],
    'bootstrap': [True]}
    rf_model = RandomForestClassifier(random_state=42)
    rf_grid = GridSearchCV(
    estimator=rf_model,
    param_grid=rf_params_reduced,
    cv=3,
    scoring='f1_weighted',
    n_jobs=-1,
    verbose=2
    )
    print("\nTuning Random Forest model (reduced parameters)...")
    rf_grid.fit(x_train, y_train)
    print(f"\nBest parameters for Random Forest: {rf_grid.best_params_}")
    rf_best_model = rf_grid.best_estimator_
    rf_best_score = rf_grid.best_score_
    print(f"Best F1 Score for Random Forest (CV): {rf_best_score:.4f}")
    predicted = rf_best_model.predict(x_test)
    precision, recall, fscore, support = score(y_test, predicted, average='macro')
    
    # Log metrics
    mlflow.log_metric("Precision_test", precision)
    mlflow.log_metric("Recall_test", recall)
    mlflow.log_metric("F1_score_test", fscore)
    
    # Log the trained model as an artifact
    mlflow.sklearn.log_model(rf_model, artifact_path="ML_models")
# Out:
# Tuning Random Forest model (reduced parameters)...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
#
# Best parameters for Random Forest: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Best F1 Score for Random Forest (CV): 0.9352
# 2024/12/09 16:37:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGBoost at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0/runs/e8040dcf41324e53befeaf54d186d1b3
# 🧪 View experiment at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0

# %% [markdown]
# # Test avec SMOTE

# %%
from imblearn.over_sampling import SMOTE

method= SMOTE()

# %%
# Start MLflow run for XGBoost with SMOTE
with mlflow.start_run(run_name='XGBoost with SMOTE'):
    mlflow.log_param("data_train", "../data/customer_churn_train.csv")
    mlflow.log_param("data_test", "../data/customer_churn_test.csv")
    mlflow.log_param("data_version", "v1.0")
    smote = SMOTE(random_state=42)

    # Apply SMOTE to the training data
    X_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

    # Initialize XGBoost model
    xgb = XGBClassifier(random_state=42)


    # Fit the model with SMOTE
    xgb.fit(X_train_smote, y_train_smote)

    # Make predictions
    y_pred = xgb.predict(x_test)

    # Compute evaluation metrics
    conf_matrix = confusion_matrix(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)
    f1 = f1_score(y_test, y_pred, average='weighted')

    # Log model parameters, metrics, and model itself in MLflow
    mlflow.set_tag(key="model", value="XGBoost with SMOTE")
    mlflow.log_params(xgb.get_params())
    precision, recall, fscore, support = score(y_test, predicted, average='macro')
    
    # Log metrics
    mlflow.log_metric("Precision_test", precision)
    mlflow.log_metric("Recall_test", recall)
    mlflow.log_metric("F1_score_test", fscore)

    # Log the trained model
    mlflow.xgboost.log_model(xgb, artifact_path="ML_models")

    # Print results
    print("Model: XGBoost with SMOTE")
    print("Confusion Matrix:\n", conf_matrix)
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 2024/12/09 16:38:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model: XGBoost with SMOTE
# Confusion Matrix:
#  [[38754  6332]
#  [  568 55388]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92     45086
#            1       0.90      0.99      0.94     55956
#
#     accuracy                           0.93    101042
#    macro avg       0.94      0.92      0.93    101042
# weighted avg       0.94      0.93      0.93    101042
#
# 🏃 View run XGBoost with SMOTE at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0/runs/28cdfdf5d42d4ea0aebb8db21a0fde45
# 🧪 View experiment at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0

# %%
# Start MLflow run for Random Forest with SMOTE
with mlflow.start_run(run_name='RandomForest with SMOTE'):
    mlflow.log_param("data_train", "../data/customer_churn_train.csv")
    mlflow.log_param("data_test", "../data/customer_churn_test.csv")
    mlflow.log_param("data_version", "v1.0")
    
    # Apply SMOTE to the training data
    smote = SMOTE(random_state=42)
    X_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

    # Initialize Random Forest model
    rf = RandomForestClassifier(random_state=42)

    # Fit the model with SMOTE
    rf.fit(X_train_smote, y_train_smote)

    # Make predictions
    y_pred = rf.predict(x_test)

    # Compute evaluation metrics
    conf_matrix = confusion_matrix(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)
    f1 = f1_score(y_test, y_pred, average='weighted')

    # Log model parameters, metrics, and model itself in MLflow
    mlflow.set_tag(key="model", value="RandomForest with SMOTE")
    mlflow.log_params(rf.get_params())
    
    # Compute precision, recall, and F1 score
    precision, recall, fscore, support = score(y_test, y_pred, average='macro')
    
    # Log metrics
    mlflow.log_metric("Precision_test", precision)
    mlflow.log_metric("Recall_test", recall)
    mlflow.log_metric("F1_score_test", fscore)

    # Log the trained model
    mlflow.sklearn.log_model(rf, artifact_path="ML_models")

    # Print results
    print("Model: RandomForest with SMOTE")
    print("Confusion Matrix:\n", conf_matrix)
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.6min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.6min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.6min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 2.3min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 1.3min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 2.3min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 1.3min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 2.3min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 1.3min
# 2024/12/09 16:40:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 1.2min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 2.9min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 1.2min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 2.9min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.2min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 2.9min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 2.3min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 2.2min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 2.3min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 2.1min
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 2.5min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 2.0min
# Model: RandomForest with SMOTE
# Confusion Matrix:
#  [[38665  6421]
#  [   65 55891]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     45086
#            1       0.90      1.00      0.95     55956
#
#     accuracy                           0.94    101042
#    macro avg       0.95      0.93      0.93    101042
# weighted avg       0.94      0.94      0.94    101042
#
# 🏃 View run RandomForest with SMOTE at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0/runs/e960a2f5f8494cc2990c4f087674ff90
# 🧪 View experiment at: https://dagshub.com/rami4real/mymlproject.mlflow/#/experiments/0
